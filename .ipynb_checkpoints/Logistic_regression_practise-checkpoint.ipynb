# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("./CSVs/HR_comma_sep.csv")
df.tail(10)
# Out:
#        satisfaction_level  last_evaluation  number_project
# 14989                0.43             0.57               2  \
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14992                0.40             0.48               2
# 14993                0.76             0.83               6
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left
# 14989                   159                   3              1     1  \
# 14990                   228                   5              1     1
# 14991                   257                   4              0     1
# ...

# %%
plt.xlabel("Employee Salary")
plt.ylabel("Left precentage")
plt.plot(df.)
